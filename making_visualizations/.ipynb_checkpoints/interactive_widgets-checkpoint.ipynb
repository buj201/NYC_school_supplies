# %% [markdown]
# # Exploring widgets and visualization
# In this notebook, we explore interactive visualizations using plotly.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import widgets, interactive
import re
from IPython.display import display, clear_output
# %matplotlib inline

# %%
all_years_data={}
for year in range(2006, 2013):
    all_years_data[year] = pd.read_csv('../../data/merged_data/expenditure_demo_account_year_{}.csv'.format(year), index_col=0)

# %% [markdown]
# Now that we've read in the data, we next clean the "Name" feature for each year:

# %%
unique_schools = []
for year in all_years_data:
    all_years_data[year].Name = all_years_data[year].Name.map(lambda x: str(x).strip()) #strip whitespace
    all_years_data[year].Name = all_years_data[year].Name.map(lambda x: re.sub('[^a-zA-Z0-9\s]','',x)) #strip non alphanumeric characters
    all_years_data[year].Name = all_years_data[year].Name.map(lambda x: str(x).upper()) #make uppercase
    unique_schools.extend(list(all_years_data[year].Name))
unique_schools = list(set(unique_schools))
print unique_schools
# Out:
# ['PS 105 SEN ABRAHAM BERNSTEIN', 'METROPOLITAN EXPEDITIONARY LEARNING SCHOOL', 'SECONDARY SCHOOL FOR JOURNALISM', 'PS 315 DIST 22', 'PS 287 BAILEY K ASHFORD', 'IS 211 JOHN WILSON', 'PS 123 SUYDAM', 'THE URBAN ASSEMBLY ACADEMY OF GOVERNMENT AND LAW', 'ASTOR COLLEGIATE ACADEMY', 'REPERTORY COMPANY HIGH SCHOOL FOR THEATRE ARTS', 'HIGH SCHOOL FOR INNOVATION IN ADVERTISING AND ME', 'PS 270', 'PS 277', 'BRONX ACADEMY OF LETTERS', 'PS 093 WILLIAM H PRESCOTT', 'THE UPPER CARROLL SCHOOL', 'HARLEM RENAISSANCE HIGH SCHOOL', 'PS 110 THEODORE SCHOENFELD', 'ELLA BAKER SCHOOL', 'FLUSHING INTERNATIONAL HIGH SCHOOL', 'PS 306', 'ALFRED E SMITH CAREER AND TECHNICAL EDUCATION H', 'PS 019 JUDITH K WEISS', 'PS 126 JACOB AUGUST RIIS', 'FIORELLO H LAGUARDIA HIGH SCHOOL OF MUSIC  ART', 'PS 033 EDWARD M FUNK', 'BROOKLYN HIGH SCHOOL FOR LEADERSHIP AND COMMUNIT', 'NEIGHBORHOOD SCHOOL', 'PS 152 DYCKMAN VALLEY', 'PS 181 BROOKFIELD', 'MS 255 SALK SCHOOL OF SCIENCE', 'PS 121 NELSON A ROCKEFELLER', 'MOTT HALL HIGH SCHOOL', 'SCIENCE SKILLS CENTER HIGH SCHOOL FOR SCIENCE', 'PS 153 HELLEN KELLER', 'INTERNATIONAL HIGH SCHOOL AT LAGUARDIA COMMUNITY', 'PS 100 GLEN MORRIS', 'NEW EXPLORERS HIGH SCHOOL', 'PS 132 GARRET A MORGAN', 'PS 191 PAUL ROBESON', 'JHS 126 JOHN ERICSSON', 'FREDERICK DOUGLASS ACADEMY V MIDDLE SCHOOL', 'BROOKLYN GENERATION SCHOOL', 'PS 247 BROOKLYN', 'PS 225 THE EILEEN E ZAGLIN', 'GREGORIO LUPERON HIGH SCHOOL FOR SCIENCE AND MAT', 'PS 134 HENRIETTA SZOLD', 'BELMONT PREPARATORY HIGH SCHOOL', 'CYNTHIA JENKINS SCHOOL', 'PS 205 FIORELLO LAGUARDIA', 'WILLIAM E GRADY CAREER AND TECHNICAL EDUCATION', 'PS 220 MOTT HAVEN VILLAGE SCHOOL', 'IS 136 CHARLES O DEWEY', 'URBAN ASSEMBLY GATEWAY SCHOOL FOR TECHNOLO', 'PS 186 DR IRVING A GLADSTONE', 'HILLSIDE ARTS  LETTERS ACADEMY', 'PS 188 KINGSBURY', 'SOUTH BRONX ACADEMY FOR APPLIED MEDIA', 'PS 200 JAMES M SMITH', 'KAPPA V', 'FRANK SINATRA SCHOOL OF THE ARTS HIGH SCHOOL', 'PS 147 ISSAC REMSEN', 'PS 028 WRIGHT BROTHERS', 'QUEST TO LEARN', 'IS 231 MAGNETECH 2000', 'WEST PREP ACADEMY', 'PS 307 DANIEL HALE WILLIAMS', 'WILLIAMSBURG HIGH SCHOOL FOR ARCHITECTURE AND DE', 'MS 223THE LABORATORY SCHOOL OF FINANCE AND TECH', 'UNIVERSITY NEIGHBORHOOD HIGH SCHOOL', 'W H MAXWELL CAREER AND TECHNICAL EDUCATION HIG', 'JHS 062 THE DITMAS', 'PS 236 MILL BASIN', 'BRONX HEALTH SCIENCES HIGH SCHOOL', 'JHS 164 EDWARD W STITT', 'EAST FORDHAM ACADEMY FOR THE ARTS', 'PS 149 SOJOURNER TRUTH', 'PS 243 WEEKSVILLE', 'PS 273', 'PS 084 JOSE DE DIEGO', 'PS 290 MANHATTAN NEW SCHOOL', 'IS 228 DAVID A BOODY', 'BRONX REGIONAL HIGH SCHOOL', 'BRONX HIGH SCHOOL FOR MEDICAL SCIENCE', 'PSMS 031 THE WILLIAM LLOYD GARRISON', 'FOREIGN LANGUAGE ACADEMY OF GLOBAL STUDIES', 'PS 233 LANGSTON HUGHES', 'EXCELSIOR PREPARATORY HIGH SCHOOL', 'PS 189 LINCOLN TERRACE', 'PS 040 GEORGE W CARVER', 'METROPOLITAN CORPORATE ACADEMY HIGH SCHOOL', 'HIGH SCHOOL FOR LAW ENFORCEMENT AND PUBLIC SAFET', 'MS 201X SCL THEATRE ARTS  RES', 'PS 096', 'PS 173 FRESH MEADOWS', 'PS 124 YUNG WING', 'PS 041 NEW DORP', 'FANNIE LOU HAMER MIDDLE SCHOOL', 'PS 146 EDWARD COLLINS', 'PS 105 THE BAY SCHOOL', 'PS 052 JOHN C THOMPSON', 'PS 376', 'PS 163 ALFRED E SMITH', 'BRONX INTERNATIONAL HIGH SCHOOL', 'THE SCHOOL OF DISCOVERY', 'PS 194 COUNTEE CULLEN', 'JHS 049 WILLIAM J GAYNOR', 'HIGH SCHOOL M560  CITY AS SCHOOL', 'JHS 151 LOU GEHRIG', 'PS 333 MANHATTAN SCHOOL FOR CHILDREN', 'PS 309 GEORGE E WIBECAN', 'PS 208 ALAIN L LOCKE', 'PS 144 COL JEROMUS REMSEN', 'LEADERSHIP AND PUBLIC SERVICE HIGH SCHOOL', 'GATEWAY SCHOOL FOR ENVIRONMENTAL RESEARCH AND TE', 'BRONX GUILD A NEW YORK CITY OUTWARD BOUND SCHOO', 'JHS 113OLD 294 EDMONDS CNTR', 'QUEENS COLLEGIATE A COLLEGE BOARD SCHOOL', 'ANDRIES HUDDE', 'BROOKLYN LAB SCHOOL', 'PS 101 THE VERRAZANO', 'FREDERICK DOUGLASS ACADEMY', 'MOTT HALL III', 'JHS 057 WHITELAW REID', 'YOUNG SCHOLARS ACADEMY FOR DISCOVERY AND EXPLOR', 'PS 183 DANIEL CHAPPIE JAMES', 'MANHATTAN BUSINESS ACADEMY', 'PS 094 THE HENRY LONGFELLOW', 'PS 39 FRANCIS J MURPHY JR', 'PS 195 MANHATTAN BEACH' ...

# %%
matches = [re.search('CONEY', name) for name in unique_schools]

# %%
match = [i.string for i in matches if i != None]
print match
# Out:
# ['PS 100 THE CONEY ISLAND']

# %% [markdown]
# Great. Now let's implement our UI for searching.

# %%
def search_function(Search):
    
    Search = Search.value
    
    ## Get school_names
    unique_schools = []
    for year in all_years_data:
        all_years_data[year].Name = all_years_data[year].Name.map(lambda x: str(x).strip()) #strip whitespace
        all_years_data[year].Name = all_years_data[year].Name.map(lambda x: re.sub('[^a-zA-Z0-9\s]','',x)) #strip non alphanumeric characters
        all_years_data[year].Name = all_years_data[year].Name.map(lambda x: str(x).upper()) #make uppercase
        unique_schools.extend(list(all_years_data[year].Name))
    unique_schools = list(set(unique_schools))
    
    ## Search through school names
    upper_school = re.sub('[^0-9a-zA-Z\s]', '', Search).upper()
    matches = [re.search(upper_school, name) for name in unique_schools]
    matching_schools = [i.string for i in matches if i != None]
    if len(matching_schools)<20:
        return matching_schools
    else:
        print '{} results found- here are 20 results. Re-search using more specific search terms.'.format(len(matching_schools))
        return matching_schools[0:30]

def plot_school(school):
    fig = plt.figure(figsize=(16,16))
    total_per_student = {}
    mean_by_T1_status = {}
    title_1 = {'Title 1':[],'non-Title 1':[]}
    for year in all_years_data:
        
        #Get group mean for comparison
        if all_years_data[year].loc[all_years_data[year]['Name'] == school,'Title_1'].isin([1]).values:
            title_1['Title 1'].append(year)
            mean_by_T1_status[year] = all_years_data[year].loc[all_years_data[year]['Title_1'] == 1,'Total'].mean()
        else:
            title_1['non-Title 1'].append(year)
            mean_by_T1_status[year] = all_years_data[year].loc[all_years_data[year]['Title_1'] == 0,'Total'].mean()
        
        #If school exists, get data for year
        if len(all_years_data[year].loc[all_years_data[year]['Name'] == school,'Total'])>0:
            total_per_student[year] = all_years_data[year].loc[all_years_data[year]['Name'] == school,'Total']
    
    mean_by_T1_status = pd.DataFrame.from_dict(mean_by_T1_status, orient='index')
    mean_by_T1_status.sort(inplace=True)
    total_per_student = pd.DataFrame.from_dict(total_per_student, orient='index')
    total_per_student.sort(inplace=True)
    
    
    ##Ax one- total expenditure comparison
    ax1 = plt.subplot(211)
    ax1.plot(total_per_student.index, total_per_student.values, label='Expenditures per student at {}'.format(school.title()))
    
    comparison_label = 'Comparison group:\n'
    #Make label for comparison plot:
    if len(title_1['Title 1']) == 0:
        comparison_label = comparison_label + 'Average expenditures across all non-Title 1 schools citywide'
    elif len(title_1['non-Title 1']) == 0:
        comparison_label = comparison_label + 'Average expenditures across all Title 1 schools citywide'
    else: ##Need to specify years for comparison
        comparison_label = comparison_label + 'Average expenditures across Title 1 schools (years {})\nand non-Title 1 schools (years {})'.format(str(title_1['Title 1']).strip('[]'),str(title_1['non-Title 1']).strip('[]'))
    
    ax1.plot(mean_by_T1_status.index, mean_by_T1_status.values, label=comparison_label)
    title = 'Total expenditures per student by year'
    ax1.set_title(title)
    ax1.set_xlabel('Year')
    ax1.set_ylabel('Total expenditures per student ($)')
    ax1.set_xlim((2006,2012))
    ax1.ticklabel_format(useOffset=False)
    ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
          fancybox=True, shadow=True, ncol=1)
    
    ##Ax2- pie chart
    
    plt.show()
    return 

def update_dropdown(search):
    global container
    clear_output()
    schools = search_function(search)
    if len(schools)>1:
        plot_school(schools[0])
        select_from = interactive(plot_school, school=widgets.Dropdown(options = schools, description = 'Select school to plot: '))
        container.children=[Search,select_from]
    if len(schools)==1:
        plot_school(schools[0])
        select_from = interactive(plot_school, school=widgets.Dropdown(options = schools, description = 'Select school to plot: '))
        container.children=[Search,select_from]
    if len(schools)==0:
        print '{} not found- please search for a different school'.format(Search.value)
        select_from = interactive(plot_school, school=widgets.Dropdown(options = schools, description = 'Select school to plot: '))
        container.children=[Search,select_from]

# %%
container = widgets.Box()
container.border_color = 'red'
container.border_style = 'dotted'
container.border_width = 3
Search = widgets.Text(description='Search:', value='Bronx Lab')
container.children=[Search]
display(container)
Search.on_submit(update_dropdown)

# %%
import matplotlib.patches as mpatches

def make_pie_plot(year, DBN):
    plt.gcf()
    matches = [re.search(r'_All_Funds', x) for x in list(all_years_data[year].columns)]
    matches = [x for x in matches if x is not None]
    matches = [x.string for x in matches]

    matches_keys = [' '.join(re.findall('[A-Z][^A-Z]*', x)) for x in matches]
    matches_keys = [re.sub('_',' ', x) for x in matches_keys]
    matches_keys = [re.sub('  ', ' ', x) for x in matches_keys]
    matches_keys = [re.sub(' All Funds', '', x) for x in matches_keys]
    
    map_cols_to_keys = dict(zip(matches, matches_keys))
    
    target_school = all_years_data[year].loc[DBN, matches]
    target_school.index = [map_cols_to_keys[x] for x in target_school.index]
    target_school.sort(inplace=True, ascending=False)
    target_school.name = ''
    
    possible_categories = ['Ancillary Support Services', 'Building Services',
                           'Central Administration', 'Central Instructional Support',
                           'Classroom Instruction', 'Field Support',
                           'Instructional Support Srcs', 'Instructional Support and Administration',
                           'Leadership Supervision Support', 'Other Field Support Costs',
                           'Referral and Evaluation Services', 'Other']
    color_scale = [plt.get_cmap('Paired')(i) for i in np.linspace(.1, 1, len(possible_categories))]
    map_keys_to_colors = dict(zip(possible_categories,color_scale))
    
    non_negligible = (target_school/target_school.sum())[(target_school/target_school.sum())>0.025]
    non_negligible['Other'] = 1.0-non_negligible.sum()
    
    colors=[map_keys_to_colors[x] for x in non_negligible.index]
    
    handles = [mpatches.Patch(color=map_keys_to_colors[x], label=str(x)) for x in non_negligible.index]
    return handles, plt.pie(non_negligible, autopct=(lambda x: str(round(x,1))+'%'), radius=1.2, colors=colors, shadow=True, pctdistance=0.8)

# %%
def make_all_subs(DBN):
    handles = []
    handle_labels = []
    plt.figure(figsize=(16,12))
    for year in range(2006,2010):
        plt.subplot(3,4, year-2001)
        plt.title(str(year))
        plots = make_pie_plot(year, DBN)
        handles.extend(plots[0])
        plots[1]
    for year in range(2010, 2013):
        plt.subplot(3,4, year-2001)
        plt.title(str(year))
        plots = make_pie_plot(year, DBN)
        handles.extend(plots[0])
        plots[1]
    legend_corner = plt.subplot(3,4,12)
    legend_corner.axis('off')
    unique_handles = []
    for patch in handles:
        if patch.get_label() in handle_labels:
            pass
        else:
            handle_labels.append(patch.get_label())
            unique_handles.append(patch)
    plt.legend(handles=unique_handles, fontsize='medium', loc='center', title='Legend')

# %%
make_all_subs('M110')

# %%
plt.get_cmap('hsv')(0)
# Out:
# (1.0, 0.0, 0.0, 1.0)
